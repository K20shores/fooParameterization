# %%
from foo.parameterization import Foo22, ModifiedFoo22
from foo.utils.ranges import foo_range

import matplotlib.pyplot as plt

# %%
Foo22().compute(2)
# Out:
# 33.510321638291124

# %%
ModifiedFoo22().compute(2)
# Out:
# 33.510321638291124

# %%
param = Foo22()
param.step1 = lambda x: x**2
param.compute(2)
# Out:
# 16.755160819145562

# %%
Rs = foo_range()
foo22 = Foo22().compute(Rs)

# %%
fig, ax = plt.subplots(dpi=300)

ax.plot(Rs, foo22, label='foo')

ax.set_title('Parameterized sea-spray physics from Foo et. al')
ax.set_xlabel('R')
ax.set_ylabel('parameterization')

for spine in ['top', 'bottom', 'left', 'right']:
    ax.spines[spine].set_visible(False)

ax.tick_params(width=0)
ax.grid(alpha=0.35)
ax.legend()
